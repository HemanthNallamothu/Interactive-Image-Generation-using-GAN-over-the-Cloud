# %%
import os
os.chdir('GAN_Model/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23544/4286953262.py in <module>
#       1 import os
# ----> 2 os.chdir('pytorch-CycleGAN-and-pix2pix/')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'pytorch-CycleGAN-and-pix2pix/'

# %%
# %%capture
# !pip install wandb -qqq

# %%
import wandb

wandb.login()
# Out:
# True

# %%
# !python train.py --dataroot ./datasets/facades --name facades_label2photo --model cycle_gan --use_wandb --gpu_ids -1
# Out:
# ^C

# %%
import matplotlib.pyplot as plt

# %%
# !python test.py --dataroot datasets/facades/Output --name facades_label2photo_pretrained --model test --no_dropout --use_wandb --gpu_ids -1
# Out:
# ----------------- Options ---------------
# C:\Users\Hemanth\AppData\Local\Programs\Python\Python37\lib\site-packages\torchvision\transforms\transforms.py:288: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# wandb: Currently logged in as: hemanthnallamothu (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run facades_label2photo_pretrained
# wandb:  View project at https://wandb.ai/hemanthnallamothu/CycleGAN-and-pix2pix
# wandb:  View run at https://wandb.ai/hemanthnallamothu/CycleGAN-and-pix2pix/runs/2broujnb
# wandb: Run data is saved locally in C:\Users\Hemanth\Notebooks\Project\Mini Project\pytorch-CycleGAN-and-pix2pix\wandb\run-20220226_102659-2broujnb
# ...

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/Input6_real.png')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23544/790382550.py in <module>
# ----> 1 img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/Input6_real.png')
#       2 plt.imshow(img)
#
# c:\users\hemanth\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2137 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2138 def imread(fname, format=None):
# -> 2139     return matplotlib.image.imread(fname, format)
#    2140
#    2141
#
# c:\users\hemanth\appdata\local\programs\python\python37\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# -> 1560     with img_open(fname) as image:
# ...

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/Input5_fake.png')
plt.imshow(img)
